# %%
import numpy as np
from glob import glob
from pathlib import Path 
import natsort
import os
from PIL import Image
import cv2
from numpy import asarray
import imageio
from natsort import natsorted

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img = Image.new('RGB',(700,700),(0,0,0))
img.save("ligne.png","PNG")

# %%
black = Image.open("/content/drive/MyDrive/proce/pathologiques/pred ligne/image1-1.jpg")
black.save('/content/drive/MyDrive/proce/pathologiques/image1-1.png')

# %%
black = Image.open("/content/drive/MyDrive/proce/pathologiques/patches/image1-0.jpg")
Image1copy=black.copy()

path = "/content/drive/MyDrive/proce/saines/used/"
files = os.listdir(path)
for name in files : 
  print(name)
  images_path= path + name
  image = Image.open(images_path)
  Image1copy.paste(image, (0, 0))
  Image1copy.save("/content/drive/MyDrive/proce/saines/Nouveau dossier (2)/"+ name )
# Out:
# image1-0.jpg
# image1-1.jpg
# image1-2.jpg
# image1-3.jpg
# image1-4.jpg
# image1-5.jpg
# image1-6.jpg
# image1-7.jpg
# image1-8.jpg
# image1-9.jpg
# image1-10.jpg
# image1-11.jpg
# image1-12.jpg
# image1-13.jpg
# image1-14.jpg
# image1-15.jpg
# image2-0.jpg
# image2-1.jpg
# image2-2.jpg
# image2-3.jpg
# image2-4.jpg
# image2-5.jpg
# image2-6.jpg
# image2-7.jpg
# image2-8.jpg
# image2-9.jpg
# image2-10.jpg
# image2-11.jpg
# image2-12.jpg
# image2-13.jpg
# image2-14.jpg
# image2-15.jpg
# image3-0.jpg
# image3-1.jpg
# image3-2.jpg
# image3-3.jpg
# image3-4.jpg
# image3-5.jpg
# image3-6.jpg
# image3-7.jpg
# image3-8.jpg
# image3-9.jpg
# image3-10.jpg
# image3-11.jpg
# image3-12.jpg
# image3-13.jpg
# image3-14.jpg
# image3-15.jpg
# image4-0.jpg
# image4-1.jpg
# image4-2.jpg
# image4-3.jpg
# image4-4.jpg
# image4-5.jpg
# image4-6.jpg
# image4-7.jpg
# image4-8.jpg
# image4-9.jpg
# image4-10.jpg
# image4-11.jpg
# image4-12.jpg
# image4-13.jpg
# image4-14.jpg
# image4-15.jpg
# image5-0.jpg
# ...
