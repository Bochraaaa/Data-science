# %%
import PIL
from PIL import Image
import cv2 
import matplotlib.pyplot as plt

# %%
image = cv2.imread("/content/drive/MyDrive/mémoire/fond d'oeil drive/fond/01.png")
#cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
fig, ax = plt.subplots()
ax.imshow(image, cmap =plt.cm.gray )

# %%
b,g,r = cv2.split(image)
ax.imshow(image, cmap =plt.cm.gray )
ax.imshow(g, cmap =plt.cm.gray )

# %%
cv2.imwrite("/content/drive/MyDrive/bfond1.png", b)
cv2.imwrite("/content/drive/MyDrive/rfond1.png",r)
# Out:
# True

# %%
real = cv2.imread("/content/drive/MyDrive/mémoire/segmented_img_first_grp/1image_test.tiff")
cv2.imwrite("/content/drive/MyDrive/real.png", real)
# Out:
# True
