# %%
import numpy as np

from skimage import io
from skimage import data
import matplotlib.pyplot as plt
from skimage import morphology
from matplotlib.pyplot import imshow,get_cmap 
import cv2

# %% [markdown]
# Création de l'élément structurant

# %%
imshow(morphology.rectangle(2,1), cmap = get_cmap('gray'))

# %% [markdown]
# lecture d'une image et conversion niveau de gris

# %%
image = cv2.imread("/content/drive/MyDrive/black.png")
image1 = cv2.imread("/content/drive/MyDrive/OD detection/01.png")
grayscale = cv2.cvtColor(image1, cv2.COLOR_RGB2GRAY)
fig, ax = plt.subplots()
ax.imshow(grayscale, cmap=plt.cm.gray)
cv2.imwrite('/content/drive/MyDrive/python_grey.png',grayscale)
# Out:
# True

# %% [markdown]
# return pixels

# %%
image = cv2.imread("/content/drive/MyDrive/Nouveau dossier/openingnet03.png")
grayscale = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
fig, ax = plt.subplots()
ax.imshow(grayscale, cmap=plt.cm.gray)
fig, ax = plt.subplots()
ax.imshow(image, cmap=plt.cm.gray)
cv2.imwrite('/content/drive/MyDrive/Nouveau dossier/openingnetgrayscale.png',grayscale)
# Out:
# True

# %%
grayscale1 = cv2.imread("/content/drive/MyDrive/Nouveau dossier/Black1.png")
grayscale = cv2.cvtColor(grayscale1, cv2.COLOR_RGB2GRAY)
cv2.imwrite('/content/drive/MyDrive/Nouveau dossier/Black1.png',grayscale)
for i in range (grayscale.shape[0]): #traverses through height of the image
    #i1 = i + 1 
    for j in range (grayscale.shape[1]):
        #if(img[i][j].all() != 255 and img[i][j].all() != 0 ):
            print (grayscale[i][j])
# Out:
# True

# %%
kernel = np.ones((2,3),np.uint8)   
erosion = cv2.erode(img,kernel,iterations = 20)
