# %%
import PIL

from PIL import Image
import os

# %%
path = "/content/drive/MyDrive/mémoire/dataset/ODIR-5K RH/"
files = os.listdir(path)
for name in files : 
  image_path = path + name
  img = Image.open(image_path)
  print(name)
  w, h = img.size
  if w == 2592 :
    print("l'image est ",name)
# Out:
# 1031_right.jpg
# 1045_right.jpg
# l'image est  1045_right.jpg
# 1024_left.jpg
# 1046_right.jpg
# 1046_left.jpg
# 1045_left.jpg
# l'image est  1045_left.jpg
# 1048_left.jpg
# l'image est  1048_left.jpg
# 1024_right.jpg
# 1048_right.jpg
# l'image est  1048_right.jpg
# 1081_right.jpg
# 1081_left.jpg
# 1056_left.jpg
# 1056_right.jpg
# 116_left.jpg
# l'image est  116_left.jpg
# 116_right.jpg
# l'image est  116_right.jpg
# 11_right.jpg
# l'image est  11_right.jpg
# 11_left.jpg
# l'image est  11_left.jpg
# 1290_left.jpg
# l'image est  1290_left.jpg
# 1290_right.jpg
# l'image est  1290_right.jpg
# 1263_right.jpg
# 1373_right.jpg
# 1377_left.jpg
# 1303_right.jpg
# 1373_left.jpg
# 1377_right.jpg
# 1309_left.jpg
# l'image est  1309_left.jpg
# 1309_right.jpg
# l'image est  1309_right.jpg
# 139_right.jpg
# l'image est  139_right.jpg
# 139_left.jpg
# l'image est  139_left.jpg
# 1853_right.jpg
# l'image est  1853_right.jpg
# 179_right.jpg
# l'image est  179_right.jpg
# 179_left.jpg
# ...
